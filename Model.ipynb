# %%
import numpy as np, matplotlib.pyplot as plt, tensorflow as tf, scipy.io, os, IPython.display as ipd, librosa
# %matplotlib inline

# %%
#Load data
os.chdir("/Volumes/TOSHIBA/MSD100/")
Data_train = np.load('Data_train.npy')
Data_test = np.load('Data_test.npy')
Data_train_output = np.load('Y_Data_train.npy')
Data_test_output= np.load('Y_Data_test.npy')

# %%
Data_test_output.shape
# Out:
# (25092, 5512)

# %%
ipd.Audio(Data_train[299,:],rate=5512)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(Data_train_output[299,:],rate=5512)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#Inputs and outputs

# %%
#Number of nodes for each kayer of the neural network

# %%
#Hyperparapeters

# %%
#Layers

# %%
#Loss function

# %%
#Optimizer

# %%
#Training loop
